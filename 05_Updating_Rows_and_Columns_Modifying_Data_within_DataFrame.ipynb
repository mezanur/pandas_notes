# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 60)

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
bd_filt = (df['Country'] == 'Bangladesh') & ~(df['SalaryUSD'].isna())

# %%
in_filt = (df['Country'] == 'India') & ~(df['SalaryUSD'].isna())

# %%
df[in_filt]
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 149         I am a developer by profession      Yes  36.0         31   Yearly
# 227         I am a developer by profession      Yes  24.0         19   Yearly
# 279         I am a developer by profession      Yes   NaN         14  Monthly
# 322         I am a developer by profession      Yes  24.0         18  Monthly
# 414         I am a developer by profession      Yes  24.0         14   Yearly
# ...                                    ...      ...   ...        ...      ...
# 64991       I am a developer by profession       No   NaN         19   Yearly
# 65028       I am a developer by profession      Yes   NaN         19   Yearly
# 65517       I am a developer by profession      Yes   NaN         15   Yearly
# 65523       I am a developer by profession      Yes   NaN         18  Monthly
# 65584       I am a developer by profession      Yes   NaN         19  Monthly
#
#              CompTotal  SalaryUSD Country  CurrencyDesc CurrencySymbol  \
# Respondent
# 149         21000000.0   293196.0   India  Indian rupee            INR
# 227           840000.0    11728.0   India  Indian rupee            INR
# 279           900000.0   150792.0   India  Indian rupee            INR
# 322            25000.0     4188.0   India  Indian rupee            INR
# 414          1700000.0    23735.0   India  Indian rupee            INR
# ...                ...        ...     ...           ...            ...
# 64991        2500000.0    34904.0   India  Indian rupee            INR
# 65028          55000.0      768.0   India  Indian rupee            INR
# 65517        1200000.0    16754.0   India  Indian rupee            INR
# 65523         450000.0    75396.0   India  Indian rupee            INR
# 65584          15000.0     2508.0   India  Indian rupee            INR
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 149                                Cassandra;MySQL;PostgreSQL
# 227                                                   MongoDB
# 279         Cassandra;Elasticsearch;Firebase;Microsoft SQL...
# 322                                    DynamoDB;MongoDB;MySQL
# 414                                                PostgreSQL
# ...                                                       ...
# 64991                                                     NaN
# 65028                                                 MongoDB
# 65517                                                 MongoDB
# 65523       Cassandra;Elasticsearch;MariaDB;MongoDB;MySQL;...
# 65584                                    Microsoft SQL Server
#
#                                            DatabaseWorkedWith  \
# Respondent
# 149                                          MySQL;PostgreSQL
# 227                                                     MySQL
# 279                                 MongoDB;PostgreSQL;SQLite
# 322                                    DynamoDB;MongoDB;MySQL
# 414                                                PostgreSQL
# ...                                                       ...
# 64991                                                     NaN
# 65028                                    Firebase;MySQL;Redis
# 65517                                    Microsoft SQL Server
# 65523       Cassandra;DynamoDB;Elasticsearch;MariaDB;Mongo...
# 65584                                    Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 149         Developer, back-end;Developer, QA or test;DevO...
# 227                                       Developer, back-end
# 279                                     Developer, full-stack
# 322         Data scientist or machine learning specialist;...
# 414         Data scientist or machine learning specialist;...
# ...                                                       ...
# 64991       Developer, back-end;Developer, desktop or ente...
# 65028                   Developer, back-end;Developer, mobile
# 65517                                   Developer, full-stack
# 65523       Developer, back-end;Developer, front-end;Devel...
# 65584                                     Developer, back-end
#
#                                                     EdLevel  \
# Respondent
# 149            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 227            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 279            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 322            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 414            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64991       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65028          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65517          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65523          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65584          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment    Ethnicity  \
# Respondent
# 149                                        Employed full-time   East Asian
# 227                                        Employed full-time          NaN
# 279                                        Employed full-time  South Asian
# 322                                        Employed full-time          NaN
# 414                                        Employed full-time  South Asian
# ...                                                       ...          ...
# 64991                                      Employed full-time          NaN
# 65028                                      Employed full-time          NaN
# 65517                                      Employed full-time          NaN
# 65523                                      Employed full-time          NaN
# 65584       Independent contractor, freelancer, or self-em...          NaN
#
#            Gender                                         JobFactors  \
# Respondent
# 149           Man  Languages, frameworks, and other technologies ...
# 227           Man  Languages, frameworks, and other technologies ...
# 279           Man  Specific department or team I’d be working on;...
# 322           Man  Languages, frameworks, and other technologies ...
# 414           Man  How widely used or impactful my work output wo...
# ...           ...                                                ...
# 64991         NaN  Flex time or a flexible schedule;Financial per...
# 65028         NaN  Languages, frameworks, and other technologies ...
# 65517         NaN  Flex time or a flexible schedule;Financial per...
# 65523         NaN                                                NaN
# 65584         Man              Office environment or company culture
#
#                                         JobSat  \
# Respondent
# 149                             Very satisfied
# 227         Neither satisfied nor dissatisfied
# 279                      Slightly dissatisfied
# 322                             Very satisfied
# 414                             Very satisfied
# ...                                        ...
# 64991                       Slightly satisfied
# 65028                           Very satisfied
# 65517       Neither satisfied nor dissatisfied
# 65523                           Very satisfied
# 65584                           Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 149              I am not interested in new job opportunities
# 227                           I am actively looking for a job
# 279                           I am actively looking for a job
# 322              I am not interested in new job opportunities
# 414         I’m not actively looking, but I am open to new...
# ...                                                       ...
# 64991       I’m not actively looking, but I am open to new...
# 65028       I’m not actively looking, but I am open to new...
# 65517       I’m not actively looking, but I am open to new...
# 65523                                                     NaN
# 65584                         I am actively looking for a job
#
#                                        LanguageDesireNextYear  \
# Respondent
# 149               Bash/Shell/PowerShell;C;C++;Java;Perl;Scala
# 227                                                    Python
# 279         Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 322                    HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 414                                      C++;Python;Scala;SQL
# ...                                                       ...
# 64991                                                     NaN
# 65028                                                     NaN
# 65517                            JavaScript;Python;TypeScript
# 65523                                         Rust;TypeScript
# 65584                              C#;HTML/CSS;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 149                            Bash/Shell/PowerShell;C++;Perl
# 227                                    Java;JavaScript;Python
# 279         Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 322                    HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 414                                            Python;R;Scala
# ...                                                       ...
# 64991                                                     NaN
# 65028                   C;C++;Go;HTML/CSS;Java;JavaScript;SQL
# 65517                                C#;JavaScript;TypeScript
# 65523       Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
# 65584                              C#;HTML/CSS;JavaScript;SQL
#
#                              MiscTechDesireNextYear       MiscTechWorkedWith  \
# Respondent
# 149                                    Apache Spark                      NaN
# 227                         Keras;Pandas;TensorFlow  Keras;Pandas;TensorFlow
# 279         Flutter;Node.js;React Native;TensorFlow                  Node.js
# 322                                         Node.js                  Node.js
# 414               Apache Spark;Pandas;Torch/PyTorch      Apache Spark;Pandas
# ...                                             ...                      ...
# 64991                                           NaN                      NaN
# 65028                                           NaN                  Node.js
# 65517                               Node.js;Xamarin           .NET;.NET Core
# 65523                          Node.js;React Native                  Node.js
# 65584                                          .NET                     .NET
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 149         Confluence;Jira;Github;Gitlab;Google Suite (Do...
# 227         Confluence;Jira;Github;Slack;Stack Overflow fo...
# 279         Jira;Github;Slack;Google Suite (Docs, Meet, et...
# 322         Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 414                     Github;Google Suite (Docs, Meet, etc)
# ...                                                       ...
# 64991                                                     NaN
# 65028                                            Gitlab;Slack
# 65517                                                     NaN
# 65523                                            Github;Slack
# 65584                                         Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 149         Confluence;Jira;Github;Google Suite (Docs, Mee...  Not sure
# 227                              Confluence;Jira;Github;Slack       Yes
# 279         Jira;Github;Slack;Google Suite (Docs, Meet, et...        No
# 322         Github;Slack;Trello;Google Suite (Docs, Meet, ...        No
# 414         Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# ...                                                       ...       ...
# 64991                                                     NaN       Yes
# 65028       Confluence;Github;Facebook Workplace;Stack Ove...       Yes
# 65517                                                     NaN        No
# 65523                                            Github;Slack       NaN
# 65584                                         Microsoft Teams        No
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 149                     Neutral  Critically important
# 227          Somewhat important      Fairly important
# 279         Extremely important        Very important
# 322                     Neutral      Fairly important
# 414         Extremely important      Fairly important
# ...                         ...                   ...
# 64991                   Neutral                   NaN
# 65028       Extremely important      Fairly important
# 65517        Not very important    Somewhat important
# 65523                       NaN        Very important
# 65584       Extremely important                   NaN
#
#                                                    NEWJobHunt  \
# Respondent
# 149         Just because;Curious about other opportunities...
# 227         Having a bad day (or week or month) at work;Cu...
# 279         Curious about other opportunities;Better compe...
# 322         Trouble with my direct manager;Better work/lif...
# 414         Having a bad day (or week or month) at work;Cu...
# ...                                                       ...
# 64991       Having a bad day (or week or month) at work;Tr...
# 65028       Curious about other opportunities;Growth or le...
# 65517                   Wanting to work with new technologies
# 65523                                                     NaN
# 65584                                     Better compensation
#
#                                            NEWJobHuntResearch  \
# Respondent
# 149         Read company media, such as employee blogs or ...
# 227         Company reviews from third party sites (e.g. G...
# 279         Read company media, such as employee blogs or ...
# 322         Read other media like news articles, founder p...
# 414         Read company media, such as employee blogs or ...
# ...                                                       ...
# 64991       Read company media, such as employee blogs or ...
# 65028       Read company media, such as employee blogs or ...
# 65517       Read company media, such as employee blogs or ...
# 65523                                                     NaN
# 65584       Company reviews from third party sites (e.g. G...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 149                  Once a year    Not sure  Onboarding? What onboarding?
# 227                  Once a year         Yes                           Yes
# 279             Every few months    Not sure                            No
# 322             Every few months    Not sure                            No
# 414             Every few months         Yes                            No
# ...                          ...         ...                           ...
# 64991                        NaN         NaN                           Yes
# 65028           Every few months         NaN                           Yes
# 65517                Once a year         NaN                            No
# 65523       Once every few years          No                           NaN
# 65584       Once every few years         NaN                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 149                   No  Sometimes: 1-2 days per month but less than we...
# 227                  Yes  Sometimes: 1-2 days per month but less than we...
# 279                   No                   Often: 1-2 days per week or more
# 322                  Yes  Sometimes: 1-2 days per month but less than we...
# 414                   No  Sometimes: 1-2 days per month but less than we...
# ...                  ...                                                ...
# 64991                Yes  Sometimes: 1-2 days per month but less than we...
# 65028                 No                  Rarely: 1-2 days per year or less
# 65517                NaN  Sometimes: 1-2 days per month but less than we...
# 65523                 No                                                NaN
# 65584                 No                   Often: 1-2 days per week or more
#
#                                           NEWPurchaseResearch  \
# Respondent
# 149                                                       NaN
# 227                                        Start a free trial
# 279                                                       NaN
# 322                                                       NaN
# 414                                                       NaN
# ...                                                       ...
# 64991                                                     NaN
# 65028                                      Start a free trial
# 65517                                                     NaN
# 65523       Start a free trial;Ask developers I know/work ...
# 65584                                      Start a free trial
#
#                 NEWPurpleLink  \
# Respondent
# 149               Indifferent
# 227         Hello, old friend
# 279                   Annoyed
# 322                   Annoyed
# 414         Hello, old friend
# ...                       ...
# 64991                     NaN
# 65028       Hello, old friend
# 65517                     NaN
# 65523                 Annoyed
# 65584       Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 149          Stack Overflow (public Q&A for anyone who codes)
# 227         Stack Overflow (public Q&A for anyone who code...
# 279          Stack Overflow (public Q&A for anyone who codes)
# 322         Stack Overflow (public Q&A for anyone who code...
# 414         Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64991       Stack Overflow (public Q&A for anyone who code...
# 65028        Stack Overflow (public Q&A for anyone who codes)
# 65517                                                     NaN
# 65523       Stack Overflow (public Q&A for anyone who code...
# 65584                   Stack Overflow Jobs (for job seekers)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 149         Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 227            Call a coworker or friend;Visit Stack Overflow      Windows
# 279         Meditate;Call a coworker or friend;Watch help ...        MacOS
# 322         Play games;Visit Stack Overflow;Go for a walk ...      Windows
# 414         Call a coworker or friend;Visit Stack Overflow...        MacOS
# ...                                                       ...          ...
# 64991                                                     NaN          NaN
# 65028       Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 65517                                                     NaN          NaN
# 65523       Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 65584                                    Visit Stack Overflow      Windows
#
#                              OrgSize  \
# Respondent
# 149             500 to 999 employees
# 227             100 to 499 employees
# 279             100 to 499 employees
# 322               20 to 99 employees
# 414             100 to 499 employees
# ...                              ...
# 64991           100 to 499 employees
# 65028       1,000 to 4,999 employees
# 65517           100 to 499 employees
# 65523             10 to 19 employees
# 65584             20 to 99 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 149                               Google Cloud Platform;Linux
# 227                        Docker;Google Cloud Platform;MacOS
# 279         AWS;Docker;Heroku;Kubernetes;Linux;MacOS;Micro...
# 322                                                       AWS
# 414                                    AWS;Docker;Linux;MacOS
# ...                                                       ...
# 64991                                                     NaN
# 65028                            Docker;Google Cloud Platform
# 65517                     Docker;Microsoft Azure;Raspberry Pi
# 65523                       AWS;Docker;Kubernetes;Linux;MacOS
# 65584                                                 Windows
#
#                                            PlatformWorkedWith  \
# Respondent
# 149                                                     Linux
# 227                        Android;Docker;Linux;MacOS;Windows
# 279                                Arduino;Heroku;Linux;MacOS
# 322                                                       AWS
# 414         AWS;Google Cloud Platform;iOS;Linux;MacOS;Windows
# ...                                                       ...
# 64991                                                     NaN
# 65028                               Android;AWS;MacOS;Windows
# 65517                                         Microsoft Azure
# 65523                       AWS;Docker;Kubernetes;Linux;MacOS
# 65584                                                 Windows
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 149         I have little or no influence  Straight / Heterosexual       Yes
# 227                 I have some influence  Straight / Heterosexual       Yes
# 279         I have little or no influence  Straight / Heterosexual       Yes
# 322         I have little or no influence                      NaN       Yes
# 414         I have little or no influence  Straight / Heterosexual       Yes
# ...                                   ...                      ...       ...
# 64991                                 NaN                      NaN       Yes
# 65028               I have some influence                      NaN       Yes
# 65517                                 NaN                      NaN       NaN
# 65523               I have some influence                      NaN       Yes
# 65584                                 NaN                      NaN       NaN
#
#                      SOComm  \
# Respondent
# 149           Yes, somewhat
# 227         Yes, definitely
# 279           Yes, somewhat
# 322         Yes, definitely
# 414                 Neutral
# ...                     ...
# 64991               Neutral
# 65028               Neutral
# 65517                   NaN
# 65523               Neutral
# 65584                   NaN
#
#                                                    SOPartFreq  \
# Respondent
# 149                           A few times per month or weekly
# 227                                      A few times per week
# 279                           A few times per month or weekly
# 322                           A few times per month or weekly
# 414                       Less than once per month or monthly
# ...                                                       ...
# 64991       I have never participated in Q&A on Stack Over...
# 65028                                    A few times per week
# 65517                                                     NaN
# 65523                     Less than once per month or monthly
# 65584                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 149                  Multiple times per day  Neither easy nor difficult
# 227                  Multiple times per day                        Easy
# 279                  Multiple times per day  Neither easy nor difficult
# 322                  Multiple times per day  Neither easy nor difficult
# 414                  Multiple times per day                        Easy
# ...                                     ...                         ...
# 64991       A few times per month or weekly                         NaN
# 65028                  A few times per week                         NaN
# 65517                                   NaN                         NaN
# 65523                Multiple times per day                         NaN
# 65584                                   NaN  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 149         Appropriate in length    No
# 227         Appropriate in length    No
# 279         Appropriate in length    No
# 322                      Too long   NaN
# 414         Appropriate in length    No
# ...                           ...   ...
# 64991                         NaN   NaN
# 65028                         NaN   NaN
# 65517                         NaN   NaN
# 65523                         NaN   NaN
# 65584                    Too long    No
#
#                                                UndergradMajor  \
# Respondent
# 149         Computer science, computer engineering, or sof...
# 227         Computer science, computer engineering, or sof...
# 279         Another engineering discipline (such as civil,...
# 322         Computer science, computer engineering, or sof...
# 414         Computer science, computer engineering, or sof...
# ...                                                       ...
# 64991       Computer science, computer engineering, or sof...
# 65028       Computer science, computer engineering, or sof...
# 65517       Computer science, computer engineering, or sof...
# 65523       Another engineering discipline (such as civil,...
# 65584       Computer science, computer engineering, or sof...
#
#                             WebframeDesireNextYear  \
# Respondent
# 149                                            NaN
# 227                                         Gatsby
# 279         Angular;Django;Express;React.js;Spring
# 322              Angular;Angular.js;jQuery;Laravel
# 414                                            NaN
# ...                                            ...
# 64991                                          NaN
# 65028                      Angular;React.js;Spring
# 65517                                     React.js
# 65523                                     React.js
# 65584                                      ASP.NET
#
#                                 WebframeWorkedWith  \
# Respondent
# 149                                            NaN
# 227                                   Flask;Spring
# 279         Angular;Django;Express;React.js;Spring
# 322              Angular;Angular.js;jQuery;Laravel
# 414                                            NaN
# ...                                            ...
# 64991                                          NaN
# 65028                                      Express
# 65517          Angular;ASP.NET;ASP.NET Core;jQuery
# 65523                                     React.js
# 65584                                      ASP.NET
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 149         Somewhat more welcome now than last year         70.0         5
# 227         Somewhat more welcome now than last year         45.0         5
# 279          Just as welcome now as I felt last year         50.0        10
# 322         Somewhat more welcome now than last year         42.0         1
# 414          Just as welcome now as I felt last year         36.0         8
# ...                                              ...          ...       ...
# 64991                                            NaN         40.0        22
# 65028       Somewhat more welcome now than last year         48.0         5
# 65517                                            NaN         40.0         5
# 65523        Just as welcome now as I felt last year          NaN        25
# 65584                                            NaN         35.0         4
#
#            YearsCodePro
# Respondent
# 149                   3
# 227                   2
# 279                   3
# 322                   3
# 414                   2
# ...                 ...
# 64991                17
# 65028                 1
# 65517                 3
# 65523                18
# 65584                 1
#
# [2668 rows x 60 columns]

# %%
df[bd_filt]
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 916         I am a developer by profession      Yes  33.0         24  Monthly
# 945         I am a developer by profession      Yes  31.0         24  Monthly
# 1412        I am a developer by profession      Yes  31.0         25  Monthly
# 1543        I am a developer by profession      Yes  30.0         17  Monthly
# 2123        I am a developer by profession      Yes  24.0         16  Monthly
# ...                                    ...      ...   ...        ...      ...
# 61965       I am a developer by profession      Yes   NaN         18  Monthly
# 62377       I am a developer by profession      Yes  29.0         18  Monthly
# 63751       I am a developer by profession      Yes   NaN         20  Monthly
# 64391       I am a developer by profession       No   NaN         27  Monthly
# 64998       I am a developer by profession       No   NaN         18   Weekly
#
#             CompTotal  SalaryUSD     Country      CurrencyDesc CurrencySymbol  \
# Respondent
# 916           40000.0     5652.0  Bangladesh  Bangladeshi taka            BDT
# 945           70000.0     9888.0  Bangladesh  Bangladeshi taka            BDT
# 1412         150000.0    21192.0  Bangladesh  Bangladeshi taka            BDT
# 1543          50000.0     7068.0  Bangladesh  Bangladeshi taka            BDT
# 2123          45000.0     6360.0  Bangladesh  Bangladeshi taka            BDT
# ...               ...        ...         ...               ...            ...
# 61965         30000.0     4236.0  Bangladesh  Bangladeshi taka            BDT
# 62377        125000.0    17664.0  Bangladesh  Bangladeshi taka            BDT
# 63751         80000.0    11304.0  Bangladesh  Bangladeshi taka            BDT
# 64391         17000.0     2400.0  Bangladesh  Bangladeshi taka            BDT
# 64998           546.0      300.0  Bangladesh  Bangladeshi taka            BDT
#
#                       DatabaseDesireNextYear  \
# Respondent
# 916                      Firebase;PostgreSQL
# 945                                  MongoDB
# 1412                    Microsoft SQL Server
# 1543                                 MongoDB
# 2123        Firebase;PostgreSQL;Redis;SQLite
# ...                                      ...
# 61965                   Microsoft SQL Server
# 62377                                    NaN
# 63751        Firebase;MariaDB;MongoDB;SQLite
# 64391                                    NaN
# 64998                                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 916         Elasticsearch;MariaDB;MongoDB;MySQL;Redis
# 945                                     MongoDB;MySQL
# 1412                             Microsoft SQL Server
# 1543                                            MySQL
# 2123                           MySQL;PostgreSQL;Redis
# ...                                               ...
# 61965                      Microsoft SQL Server;MySQL
# 62377                                             NaN
# 63751                                   MariaDB;MySQL
# 64391                                             NaN
# 64998                                             NaN
#
#                                                       DevType  \
# Respondent
# 916                Developer, front-end;Developer, full-stack
# 945                             Designer;Developer, front-end
# 1412                Developer, back-end;Developer, full-stack
# 1543                Developer, back-end;Developer, full-stack
# 2123                                    Developer, full-stack
# ...                                                       ...
# 61965       Developer, back-end;Developer, desktop or ente...
# 62377                                       Developer, mobile
# 63751       Data or business analyst;Developer, back-end;D...
# 64391       Data scientist or machine learning specialist;...
# 64998                                   Developer, full-stack
#
#                                                       EdLevel  \
# Respondent
# 916              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 945              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1412             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1543        Some college/university study without earning ...
# 2123             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 61965            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62377            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63751         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64391         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64998            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 916         Independent contractor, freelancer, or self-em...
# 945                                        Employed full-time
# 1412                                       Employed full-time
# 1543                                       Employed full-time
# 2123                                       Employed full-time
# ...                                                       ...
# 61965                                      Employed full-time
# 62377                                      Employed full-time
# 63751                                      Employed full-time
# 64391                                      Employed full-time
# 64998       Independent contractor, freelancer, or self-em...
#
#                   Ethnicity Gender  \
# Respondent
# 916             South Asian    Man
# 945         Southeast Asian    Man
# 1412            South Asian    Man
# 1543            South Asian    Man
# 2123            South Asian    Man
# ...                     ...    ...
# 61965                   NaN    NaN
# 62377           South Asian    Man
# 63751                   NaN    NaN
# 64391                   NaN    NaN
# 64998                   NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 916         Diversity of the company or organization;Langu...
# 945         Languages, frameworks, and other technologies ...
# 1412        Flex time or a flexible schedule;How widely us...
# 1543        Languages, frameworks, and other technologies ...
# 2123        Remote work options;How widely used or impactf...
# ...                                                       ...
# 61965                                                     NaN
# 62377       Industry that I’d be working in;Office environ...
# 63751           Specific department or team I’d be working on
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                         JobSat  \
# Respondent
# 916         Neither satisfied nor dissatisfied
# 945                         Slightly satisfied
# 1412                        Slightly satisfied
# 1543                     Slightly dissatisfied
# 2123                            Very satisfied
# ...                                        ...
# 61965       Neither satisfied nor dissatisfied
# 62377                           Very satisfied
# 63751                       Slightly satisfied
# 64391                       Slightly satisfied
# 64998       Neither satisfied nor dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 916                           I am actively looking for a job
# 945         I’m not actively looking, but I am open to new...
# 1412                          I am actively looking for a job
# 1543        I’m not actively looking, but I am open to new...
# 2123             I am not interested in new job opportunities
# ...                                                       ...
# 61965                         I am actively looking for a job
# 62377       I’m not actively looking, but I am open to new...
# 63751                         I am actively looking for a job
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 916                                           C++;Perl;Python
# 945                                       HTML/CSS;JavaScript
# 1412                                        C#;C++;TypeScript
# 1543                                       JavaScript;PHP;SQL
# 2123        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# ...                                                       ...
# 61965                              C#;HTML/CSS;JavaScript;SQL
# 62377                                                     NaN
# 63751                                        Dart;Python;Rust
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 916                C;HTML/CSS;JavaScript;PHP;R;SQL;TypeScript
# 945                                       HTML/CSS;JavaScript
# 1412                                            C#;TypeScript
# 1543                                         HTML/CSS;PHP;SQL
# 2123        Bash/Shell/PowerShell;HTML/CSS;JavaScript;SQL;...
# ...                                                       ...
# 61965                          C#;HTML/CSS;JavaScript;PHP;SQL
# 62377                                                     NaN
# 63751                                                    Dart
# 64391                                                     NaN
# 64998                                                     NaN
#
#            MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 916                        Pandas            Node.js
# 945         Node.js;Unreal Engine            Node.js
# 1412               .NET;.NET Core     .NET;.NET Core
# 1543                      Node.js                NaN
# 2123         Node.js;React Native            Node.js
# ...                           ...                ...
# 61965              .NET;.NET Core               .NET
# 62377                         NaN                NaN
# 63751        Flutter;React Native            Flutter
# 64391                         NaN                NaN
# 64998                         NaN                NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 916                                                       NaN
# 945                                    Github;Microsoft Azure
# 1412                                                   Github
# 1543        Facebook Workplace;Trello;Stack Overflow for T...
# 2123                                      Github;Gitlab;Slack
# ...                                                       ...
# 61965                                                     NaN
# 62377                                      Jira;Github;Gitlab
# 63751                                                     NaN
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 916                                                    Github        No
# 945                                                    Gitlab        No
# 1412                                                   Github       Yes
# 1543                                                   Trello  Not sure
# 2123        Github;Gitlab;Slack;Trello;Google Suite (Docs,...        No
# ...                                                       ...       ...
# 61965                                                  Github       NaN
# 62377                         Jira;Github;Gitlab;Slack;Trello        No
# 63751                                           Github;Trello        No
# 64391                                                     NaN       NaN
# 64998                                                     NaN  Not sure
#
#                    NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 916                      Neutral  Not at all important/not necessary
# 945          Extremely important                      Very important
# 1412         Extremely important  Not at all important/not necessary
# 1543          Somewhat important                  Somewhat important
# 2123         Extremely important  Not at all important/not necessary
# ...                          ...                                 ...
# 61965                        NaN                  Somewhat important
# 62377        Extremely important                Critically important
# 63751        Extremely important                      Very important
# 64391                        NaN                  Somewhat important
# 64998       Not at all important                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 916              Better compensation;Better work/life balance
# 945         Wanting to work with new technologies;Growth o...
# 1412        Better compensation;Better work/life balance;L...
# 1543        Better work/life balance;Growth or leadership ...
# 2123        Just because;Better compensation;Better work/l...
# ...                                                       ...
# 61965                                                     NaN
# 62377       Curious about other opportunities;Better compe...
# 63751                                     Better compensation
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 916         Read company media, such as employee blogs or ...
# 945         Read company media, such as employee blogs or ...
# 1412        Read company media, such as employee blogs or ...
# 1543        Read company media, such as employee blogs or ...
# 2123        Company reviews from third party sites (e.g. G...
# ...                                                       ...
# 61965                                                     NaN
# 62377       Read company media, such as employee blogs or ...
# 63751                    Personal network - friends or family
# 64391                                                     NaN
# 64998                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 916                  Once a year          No                            No
# 945                  Once a year         Yes                           Yes
# 1412                 Once a year         Yes                           Yes
# 1543        Once every few years         Yes                           Yes
# 2123                 Once a year    Not sure                            No
# ...                          ...         ...                           ...
# 61965           Every few months         NaN                           NaN
# 62377                Once a year          No                            No
# 63751                Once a year         NaN                            No
# 64391                        NaN    Not sure                           NaN
# 64998                        NaN         NaN  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 916                   No  Occasionally: 1-2 days per quarter but less th...
# 945                  Yes  Sometimes: 1-2 days per month but less than we...
# 1412                 Yes                                              Never
# 1543                 Yes  Sometimes: 1-2 days per month but less than we...
# 2123                 Yes  Sometimes: 1-2 days per month but less than we...
# ...                  ...                                                ...
# 61965                NaN  Sometimes: 1-2 days per month but less than we...
# 62377                 No                   Often: 1-2 days per week or more
# 63751                NaN                                              Never
# 64391                Yes                                                NaN
# 64998                NaN                  Rarely: 1-2 days per year or less
#
#                                           NEWPurchaseResearch  \
# Respondent
# 916         Start a free trial;Read ratings or reviews on ...
# 945                                                       NaN
# 1412                                       Start a free trial
# 1543                                                      NaN
# 2123                                                      NaN
# ...                                                       ...
# 61965       Start a free trial;Visit developer communities...
# 62377       Read ratings or reviews on third party sites l...
# 63751       Visit developer communities like Stack Overflo...
# 64391                                                     NaN
# 64998                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 916                   Annoyed
# 945                   Annoyed
# 1412              Indifferent
# 1543                   Amused
# 2123              Indifferent
# ...                       ...
# 61965                  Amused
# 62377       Hello, old friend
# 63751                  Amused
# 64391                     NaN
# 64998                     NaN
#
#                                                    NEWSOSites  \
# Respondent
# 916          Stack Overflow (public Q&A for anyone who codes)
# 945         Stack Overflow (public Q&A for anyone who code...
# 1412        Stack Overflow (public Q&A for anyone who code...
# 1543        Stack Overflow (public Q&A for anyone who code...
# 2123        Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 61965                                                     NaN
# 62377       Stack Overflow (public Q&A for anyone who code...
# 63751       Stack Overflow (public Q&A for anyone who code...
# 64391       Stack Overflow (public Q&A for anyone who code...
# 64998                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 916         Visit Stack Overflow;Watch help / tutorial vid...  Linux-based
# 945                                      Visit Stack Overflow        MacOS
# 1412        Visit Stack Overflow;Do other work and come ba...      Windows
# 1543        Play games;Call a coworker or friend;Visit Sta...      Windows
# 2123        Call a coworker or friend;Visit Stack Overflow...  Linux-based
# ...                                                       ...          ...
# 61965       Visit Stack Overflow;Visit another developer c...      Windows
# 62377       Visit Stack Overflow;Go for a walk or other ph...      Windows
# 63751       Visit Stack Overflow;Do other work and come ba...  Linux-based
# 64391                                                     NaN          NaN
# 64998                                                     NaN          NaN
#
#                          OrgSize  \
# Respondent
# 916             2 to 9 employees
# 945           10 to 19 employees
# 1412        500 to 999 employees
# 1543          20 to 99 employees
# 2123        100 to 499 employees
# ...                          ...
# 61965           2 to 9 employees
# 62377         20 to 99 employees
# 63751         20 to 99 employees
# 64391       100 to 499 employees
# 64998       100 to 499 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 916                           Google Cloud Platform;WordPress
# 945                                                       NaN
# 1412                                  Microsoft Azure;Windows
# 1543                                            Linux;Windows
# 2123        AWS;Docker;Google Cloud Platform;Linux;Slack A...
# ...                                                       ...
# 61965                                                 Windows
# 62377                         Android;Heroku;iOS;Raspberry Pi
# 63751                                          Android;Docker
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                 PlatformWorkedWith  \
# Respondent
# 916                                          Linux
# 945                                  MacOS;Windows
# 1412                       Microsoft Azure;Windows
# 1543                                 Linux;Windows
# 2123        AWS;Docker;Google Cloud Platform;Linux
# ...                                            ...
# 61965                                      Windows
# 62377                    Android;AWS;Docker;Heroku
# 63751                                      Android
# 64391                                          NaN
# 64998                                          NaN
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 916                                      NaN  Straight / Heterosexual
# 945            I have little or no influence                      NaN
# 1412        I have a great deal of influence  Straight / Heterosexual
# 1543           I have little or no influence                      NaN
# 2123           I have little or no influence  Straight / Heterosexual
# ...                                      ...                      ...
# 61965                  I have some influence                      NaN
# 62377                  I have some influence  Straight / Heterosexual
# 63751                  I have some influence                      NaN
# 64391                                    NaN                      NaN
# 64998                                    NaN                      NaN
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 916              Yes    Yes, somewhat                 A few times per week
# 945              Yes  Yes, definitely      A few times per month or weekly
# 1412             Yes  Yes, definitely                Daily or almost daily
# 1543             Yes          Neutral                 A few times per week
# 2123             Yes   No, not really  Less than once per month or monthly
# ...              ...              ...                                  ...
# 61965            NaN              NaN                                  NaN
# 62377            Yes  Yes, definitely  Less than once per month or monthly
# 63751            Yes  Yes, definitely  Less than once per month or monthly
# 64391            Yes  Yes, definitely  Less than once per month or monthly
# 64998            NaN              NaN                                  NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 916                  Multiple times per day                   Difficult
# 945                  Multiple times per day  Neither easy nor difficult
# 1412                 Multiple times per day  Neither easy nor difficult
# 1543                 Multiple times per day  Neither easy nor difficult
# 2123        A few times per month or weekly  Neither easy nor difficult
# ...                                     ...                         ...
# 61965                                   NaN                         NaN
# 62377       A few times per month or weekly                   Difficult
# 63751                Multiple times per day                         NaN
# 64391                Multiple times per day                         NaN
# 64998                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 916                      Too long    No
# 945                      Too long    No
# 1412                     Too long    No
# 1543                     Too long    No
# 2123        Appropriate in length    No
# ...                           ...   ...
# 61965                         NaN   NaN
# 62377       Appropriate in length    No
# 63751                         NaN   NaN
# 64391                         NaN   NaN
# 64998                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 916                                 Mathematics or statistics
# 945         Another engineering discipline (such as civil,...
# 1412        Another engineering discipline (such as civil,...
# 1543        Computer science, computer engineering, or sof...
# 2123        Another engineering discipline (such as civil,...
# ...                                                       ...
# 61965       Computer science, computer engineering, or sof...
# 62377       Computer science, computer engineering, or sof...
# 63751       Computer science, computer engineering, or sof...
# 64391                               Mathematics or statistics
# 64998       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 916                                             Django;Drupal
# 945                                          Express;React.js
# 1412                             Angular;ASP.NET;ASP.NET Core
# 1543                                           Express;jQuery
# 2123                                  Express;Gatsby;React.js
# ...                                                       ...
# 61965       Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery...
# 62377                                                     NaN
# 63751                                                  Django
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                            WebframeWorkedWith  \
# Respondent
# 916         Angular;Angular.js;Express;jQuery;Laravel;Reac...
# 945                                                    Vue.js
# 1412                             Angular;ASP.NET;ASP.NET Core
# 1543                                                   jQuery
# 2123                       Angular.js;Express;Gatsby;React.js
# ...                                                       ...
# 61965                                          ASP.NET;jQuery
# 62377                                                     NaN
# 63751                                 Laravel;React.js;Vue.js
# 64391                                                     NaN
# 64998                                                     NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 916         Somewhat more welcome now than last year         40.0         5
# 945         Somewhat less welcome now than last year         30.0         4
# 1412        Somewhat more welcome now than last year         30.0         6
# 1543           A lot less welcome now than last year         50.0        10
# 2123        Somewhat more welcome now than last year         40.0         7
# ...                                              ...          ...       ...
# 61965                                            NaN         48.0         8
# 62377       Somewhat more welcome now than last year         45.0         8
# 63751                                            NaN         40.0         8
# 64391                                            NaN          NaN         3
# 64998                                            NaN         25.0        15
#
#            YearsCodePro
# Respondent
# 916                   3
# 945                   4
# 1412                  6
# 1543                  8
# 2123                  6
# ...                 ...
# 61965                 4
# 62377                 4
# 63751                12
# 64391                 2
# 64998                10
#
# [184 rows x 60 columns]

# %%
schema_df.loc['ConvertedComp', 'QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.'
