# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', df.shape[1])
pd.set_option('display.max_rows', 200)

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['Age'].quantile(.10)
# Out:
# 21.0

# %%
df.quantile(.75)
# Out:
# Age                  35.0
# CompTotal        125000.0
# ConvertedComp     95000.0
# WorkWeekHrs          44.0
# Name: 0.75, dtype: float64

# %%
df.loc[df['Country']=='Bangladesh', 'ConvertedComp'].median()
# Out:
# 7068.0

# %%
df['Hobbyist'].count()
# Out:
# 64416

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Man                                                            0.910121
# Woman                                                          0.076033
# Non-binary, genderqueer, or gender non-conforming              0.007615
# Man;Non-binary, genderqueer, or gender non-conforming          0.002393
# Woman;Non-binary, genderqueer, or gender non-conforming        0.001820
# Woman;Man                                                      0.001503
# Woman;Man;Non-binary, genderqueer, or gender non-conforming    0.000514
# Name: Gender, dtype: float64

# %%
df['WorkWeekHrs'].value_counts()
# Out:
# 40.000000     19292
# 45.000000      3787
# 50.000000      2747
# 35.000000      2000
# 38.000000      1352
# 30.000000      1036
# 60.000000      1010
# 42.000000       959
# 37.000000       873
# 8.000000        813
# 48.000000       603
# 44.000000       486
# 37.500000       477
# 20.000000       453
# 36.000000       421
# 55.000000       382
# 39.000000       371
# 9.000000        360
# 32.000000       348
# 43.000000       288
# 25.000000       238
# 10.000000       227
# 70.000000       225
# 41.000000       196
# 80.000000       141
# 46.000000       104
# 5.000000         99
# 24.000000        98
# 7.000000         97
# 56.000000        85
# 54.000000        81
# 6.000000         79
# 47.000000        74
# 12.000000        71
# 15.000000        69
# 65.000000        62
# 16.000000        60
# 42.500000        56
# 28.000000        54
# 52.000000        53
# 375.000000       44
# 33.000000        42
# 160.000000       41
# 34.000000        37
# 75.000000        32
# ...

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26542
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13112
# Some college/university study without earning a degree                                 7239
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4771
# Associate degree (A.A., A.S., etc.)                                                    1843
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1690
# Primary/elementary school                                                               941
# Professional degree (JD, MD, etc.)                                                      800
# I never completed any formal education                                                  493
# Name: EdLevel, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
df.loc[df['Country']=='Bangladesh', 'EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          315
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        65
# Some college/university study without earning a degree                                 45
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     38
# I never completed any formal education                                                 14
# Primary/elementary school                                                               7
# Associate degree (A.A., A.S., etc.)                                                     3
# Professional degree (JD, MD, etc.)                                                      1
# Name: EdLevel, dtype: int64

# %%
country_grp['EdLevel'].value_counts()
# Out:
# Country      EdLevel
# Afghanistan  Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          27
#              I never completed any formal education                                                12
#              Some college/university study without earning a degree                                 7
#              Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        4
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4
#                                                                                                    ..
# Zimbabwe     Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          11
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5
#              Some college/university study without earning a degree                                 5
# ...

# %%
country_grp['ConvertedComp'].median().sort_values(ascending=False)
# Out:
# Country
# United States                                115000.0
# Switzerland                                   98599.0
# Israel                                        98064.0
# Nomadic                                       93000.0
# Andorra                                       88640.0
# Bahamas                                       86706.0
# Denmark                                       81624.0
# Norway                                        80922.0
# Iceland                                       80424.0
# Australia                                     76831.0
# Ireland                                       75669.0
# Luxembourg                                    75669.0
# Hong Kong (S.A.R.)                            71717.0
# Lao People's Democratic Republic              69927.0
# Canada                                        68068.0
# United Kingdom                                67215.0
# New Zealand                                   63890.0
# ...

# %%
country_grp['ConvertedComp'].median().sort_values(ascending=False).loc['India':'Bangladesh']
# Out:
# Country
# India          10056.0
# Haiti          10000.0
# Senegal         9582.0
# Algeria         9432.0
# Mongolia        9366.0
# Madagascar      9080.0
# Bolivia         8676.0
# Sri Lanka       8568.0
# Ghana           8544.0
# Egypt           8460.0
# Philippines     8292.0
# Cambodia        8082.0
# Tunisia         7992.0
# Indonesia       7908.0
# Cuba            7788.0
# Zimbabwe        7200.0
# Somalia         7200.0
# Bangladesh      7068.0
# Name: ConvertedComp, dtype: float64

# %%
df.groupby(['Country'])['ConvertedComp'].agg(['mean', 'median'])
# Out:
#                                                     mean    median
# Country
# Afghanistan                                148290.125000   15163.5
# Albania                                     25611.000000   15900.0
# Algeria                                     10362.812500    9432.0
# Andorra                                     88640.000000   88640.0
# Angola                                       5292.000000    5292.0
# Antigua and Barbuda                                  NaN       NaN
# Argentina                                   29010.033473   17520.0
# Armenia                                     30421.285714   21066.0
# Australia                                  146165.814767   76831.0
# Austria                                     83077.661342   51888.0
# Azerbaijan                                  14909.142857   11988.0
# Bahamas                                     86706.000000   86706.0
# Bahrain                                     39592.000000   40196.0
# ...

# %%
filt = (df['Country'] == 'Bangladesh')

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 179

# %%
country_grp['LanguageWorkedWith'].str.contains('Python')
# Out:
# --------------------------------------------------------------------
# AttributeError                     Traceback (most recent call last)
# <ipython-input-137-f83195f57315> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python')
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
df['Age'].dropna()
# Out:
# Respondent
# 4        25.0
# 5        31.0
# 8        36.0
# 9        30.0
# 10       22.0
#          ...
# 60134    22.0
# 60149    34.0
# 61111    38.0
# 61561    64.0
# 62834    17.0
# Name: Age, Length: 45446, dtype: float64

# %%
df['Age'].mad()
# Out:
# 7.2186906771091905

# %%
knowPython = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
totRespondent = country_grp['LanguageWorkedWith'].count()

# %%
totRespondent.name = 'TotalRepondents'

# %%
df[df['Country']=='United States']['LanguageWorkedWith'].count()
# Out:
# 11633

# %%
df_pctPy = pd.concat([knowPython, totRespondent], axis='columns')

# %%
df_pctPy
# Out:
#                                            KnowsPython  TotalRepondents
# Country
# Afghanistan                                         11               48
# Albania                                             13               38
# Algeria                                             40               78
# Andorra                                              3                8
# Angola                                               1                3
# Antigua and Barbuda                                  0                0
# Argentina                                          134              348
# Armenia                                             17               51
# Australia                                          524             1123
# Austria                                            205              509
# Azerbaijan                                          11               37
# Bahamas                                              1                2
# ...

# %%
df_pctPy.rename(columns={'LanguageWorkedWith':'KnowsPython'}, inplace=True)

# %%
df_pctPy['pctKnowsPyton'] = (df_pctPy['KnowsPython']/df_pctPy['TotalRepondents']) * 100

# %%
df_pctPy
# Out:
#                                            KnowPython  TotalRepondent  \
# Country
# Saint Lucia                                         1               1
# Gabon                                               1               1
# Timor-Leste                                         1               1
# Micronesia, Federated States of...                  1               1
# Guyana                                              3               4
# Montenegro                                          9              13
# Mauritania                                          2               3
# Brunei Darussalam                                   2               3
# Swaziland                                           4               6
# Cameroon                                           24              39
# Iceland                                            28              46
# Congo, Republic of the...                           3               5
# ...

# %%
df_pctPy.sort_values(by='pctKnowsPyton', ascending=False, inplace=True)

# %%
df_pctPy.loc['Bangladesh']
# Out:
# KnowsPython        179.000000
# TotalRepondents    520.000000
# pctKnowsPyton       34.423077
# Name: Bangladesh, dtype: float64

# %%
df_pctPy.columns = ['KnowPython', 'TotalRepondent', 'pctKnowPyton']
