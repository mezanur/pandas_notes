# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['Na', 'Missing', 'MISSING']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_rows', 61)
pd.set_option('display.max_columns', 60)

# %%
df['Age1stCode'].unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 4, '28', '38', '23', '27', '41', '24', '53', '26', '35',
#        '32', '40', '33', '36', '54', '48', '56', '45', '44', '34', 86,
#        '39', '51', '68', '50', '37', '47', '43', '52', '85', '64', '55',
#        '58', '49', '76', '72', '73', '83', '63'], dtype=object)

# %%
df['Age1stCode'] = df['Age1stCode'].replace('Younger than 5 years', 4)
df['Age1stCode'] = df['Age1stCode'].replace('Older than 85', 86)

# %%
df['Age1stCode'].astype(float).agg(['mean', 'median'])
# Out:
# mean      15.410345
# median    15.000000
# Name: Age1stCode, dtype: float64

# %%
df['Age1stCode'].astype(float).mode()
# Out:
# 0    15.0
# dtype: float64

# %%
df.dropna(subset=['ConvertedComp'])
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# 12                             I am a developer by profession       No  49.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# ...                                                       ...      ...   ...
# 65619       I am not primarily a developer, but I write co...      Yes   NaN
# 65625                          I am a developer by profession      Yes   NaN
# 65629                          I am a developer by profession      Yes  41.0
# 65630                          I am a developer by profession      Yes   NaN
# 65631                          I am a developer by profession      Yes   NaN
#
# ...
