# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
filt = (df['Country'] == 'Bangladesh') & (~df['ConvertedComp'].isna())

# %%
trans = df.loc[df['Trans'] == 'Yes']

# %%
trans.sort_values(by='ConvertedComp', ascending=False)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 281         I am a developer by profession       No  26.0         16  Monthly
# 44744       I am a developer by profession      Yes  56.0          6  Monthly
# 20122       I am a developer by profession      Yes   1.0         20  Monthly
# 25057       I am a developer by profession       No  47.0          9   Yearly
# 14986       I am a developer by profession      Yes  24.0          7  Monthly
# ...                                    ...      ...   ...        ...      ...
# 16615                                  NaN      Yes  54.0         16      NaN
# 18748                                  NaN      Yes   NaN         30      NaN
# 30156                                  NaN      Yes  34.0          9      NaN
# 55211                                  NaN      Yes   NaN         31      NaN
# 58839                                  NaN      Yes   NaN          5      NaN
#
#                CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 281         9.200000e+04      1104000.0   United States  United States dollar
# 44744       1.432141e+09      1000000.0          Israel    Israeli new shekel
# 20122       1.000000e+11      1000000.0       Indonesia     Indonesian rupiah
# 25057       5.800000e+05       580000.0   United States  United States dollar
# 14986       3.600000e+04       558396.0  United Kingdom        Pound sterling
# ...                  ...            ...             ...                   ...
# 16615                NaN            NaN  United Kingdom                   NaN
# 18748                NaN            NaN            Iran                   NaN
# 30156                NaN            NaN        Cambodia                   NaN
# 55211                NaN            NaN        Pakistan                   NaN
# 58839                NaN            NaN      Bangladesh                   NaN
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 281                   USD  ...                        Easy
# 44744                 ILS  ...  Neither easy nor difficult
# 20122                 IDR  ...  Neither easy nor difficult
# 25057                 USD  ...                        Easy
# 14986                 GBP  ...                        Easy
# ...                   ...  ...                         ...
# 16615                 NaN  ...                        Easy
# 18748                 NaN  ...                        Easy
# 30156                 NaN  ...                   Difficult
# 55211                 NaN  ...                        Easy
# 58839                 NaN  ...                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 281         Appropriate in length   Yes
# 44744       Appropriate in length   Yes
# 20122                    Too long   Yes
# 25057                    Too long   Yes
# 14986       Appropriate in length   Yes
# ...                           ...   ...
# 16615       Appropriate in length   Yes
# 18748                   Too short   Yes
# 30156       Appropriate in length   Yes
# 55211                   Too short   Yes
# 58839                   Too short   Yes
#
#                                                UndergradMajor  \
# Respondent
# 281                                 Mathematics or statistics
# 44744                                                     NaN
# 20122       Computer science, computer engineering, or sof...
# 25057       Another engineering discipline (such as civil,...
# 14986       Computer science, computer engineering, or sof...
# ...                                                       ...
# 16615                                                     NaN
# 18748                           Web development or web design
# 30156                                                     NaN
# 55211       Another engineering discipline (such as civil,...
# 58839       A humanities discipline (such as literature, h...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 281                                                       NaN
# 44744                                            Flask;jQuery
# 20122                                                  Vue.js
# 25057                                                     NaN
# 14986                                                     NaN
# ...                                                       ...
# 16615                                                     NaN
# 18748       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 30156                                            ASP.NET Core
# 55211                                                 Angular
# 58839                                                  Spring
#
#                                            WebframeWorkedWith  \
# Respondent
# 281                                                       NaN
# 44744                                                     NaN
# 20122                                                 Angular
# 25057                                   Django;Flask;React.js
# 14986                                                     NaN
# ...                                                       ...
# 16615                                                     NaN
# 18748       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 30156                                                     NaN
# 55211                                                 Angular
# 58839                                                  Spring
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 281          Just as welcome now as I felt last year        50.0        10
# 44744       Somewhat less welcome now than last year        50.0         2
# 20122       Somewhat less welcome now than last year         9.0         5
# 25057        Just as welcome now as I felt last year         NaN        38
# 14986          A lot less welcome now than last year        37.0        13
# ...                                              ...         ...       ...
# 16615        Just as welcome now as I felt last year         NaN        40
# 18748          A lot less welcome now than last year         NaN        30
# 30156                                            NaN         NaN         3
# 55211                                            NaN         NaN         6
# 58839                                            NaN         NaN         4
#
#            YearsCodePro
# Respondent
# 281                   3
# 44744                16
# 20122                 1
# 25057                25
# 14986                 8
# ...                 ...
# 16615                30
# 18748                30
# 30156                 8
# 55211               NaN
# 58839                 3
#
# [474 rows x 60 columns]
