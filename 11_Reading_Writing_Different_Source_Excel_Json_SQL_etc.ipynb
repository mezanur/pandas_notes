# %%
import pandas as pd

# %% [markdown]
# #### CSV files, with custom delimiter

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
bd_df = df[df['Country']=='Bangladesh']

# %%
bd_df.to_csv('data/bangladesh.csv', sep='\t')

# %% [markdown]
# #### Excel file
# **You need to have installed**
# * xlwt to write to older xls format
# * xlrd to read from older xls format
# * openpyxl to read and write newer xlsx format

# %%
bd_df.to_excel('data/bangladesh.xlsx')

# %%
df_from_xl = pd.read_excel('data/bangladesh.xlsx', index_col='Respondent')

# %%
df_from_xl.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 575                 I am a developer by profession      Yes  19.0         19
# 614                 I am a developer by profession      Yes   NaN         18
# 747         I am a student who is learning to code      Yes  21.0         15
# 916                 I am a developer by profession      Yes  33.0         24
# 945                 I am a developer by profession      Yes  31.0         24
#
#            CompFreq  CompTotal  ConvertedComp     Country  \
# Respondent
# 575             NaN        NaN            NaN  Bangladesh
# 614             NaN        NaN            NaN  Bangladesh
# 747             NaN        NaN            NaN  Bangladesh
# 916         Monthly    40000.0         5652.0  Bangladesh
# 945         Monthly    70000.0         9888.0  Bangladesh
#
#                     CurrencyDesc CurrencySymbol  ...  \
# Respondent                                       ...
# ...

# %%
df_from_xl.to_json('data/bangladesh.json')
